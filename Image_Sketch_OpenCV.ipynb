# %% [markdown]
# <a href="https://colab.research.google.com/github/HasnainShakir/Hshakir/blob/master/Image_Sketch_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Making a sketch using OpenCV**

# %% [markdown]
# ***Import required libraries and load Image***

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Open the image.
Image = cv2.imread("/content/shakir.jpg")
cv2_imshow(Image)
# Out:
# <PIL.Image.Image image mode=RGB size=388x515>

# %% [markdown]
# ***Convert the image from BGR to gray***

# %%
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=388x515>

# %% [markdown]
# ***Gaussian Blur the image, to remove Gaussian Noise***

# %%
blur_gray = cv2.GaussianBlur(gray,(5,5),900)
cv2_imshow(blur_gray)
# Out:
# <PIL.Image.Image image mode=L size=388x515>

# %% [markdown]
# ***Find edges in the image using Canny Edge Detection***

# %%
edges = cv2.Canny(blur_gray,45,90)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=388x515>

# %% [markdown]
# ***Find edges in the image using Canny Edge Detection***

# %%
ret,thre = cv2.threshold(edges,70,255,cv2.THRESH_BINARY_INV)
cv2_imshow(thre)
# Out:
# <PIL.Image.Image image mode=L size=388x515>
